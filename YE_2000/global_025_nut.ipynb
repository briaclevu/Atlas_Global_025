# %% [markdown]
# <hr>
# Patrick BROCKMANN - 10/2014<br>
# Briac LE VU - 10/2014<br>
# James ORR - 10/2014<br>
#
# <img align="left" width="40%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" \><br><br>
# <hr>

# %% [markdown]
# Notebook to visualze global ORCA025-PISCES output using PyFerret
# ---

# %% [markdown]
# #### First thing is to install the ferret extension

# %%
# %install_ext https://raw.github.com/PBrockmann/ipython-ferretmagic/master/ferretmagic.py
# Out:
# Installed ferretmagic.py. To use it, type:
#   %load_ext ferretmagic

# %% [markdown]
# #### Then load the extension

# %%
# %load_ext ferretmagic

# %% [markdown]
# #### Build a list of files from http://dods.idris.fr/rfry451/ORCA025-PIS2DIC/ in remote access and open it

# %%
# %%ferret
# use "http://prodn.idris.fr/thredds/dodsC/IDRISPUBFS/rfry451/ORCA025-PIS2DIC/GRID/mask.nc"
# use "http://prodn.idris.fr/thredds/dodsC/IDRISPUBFS/rfry451/ORCA025-PIS2DIC/MBG/Output/YE/ORCA025-PIS2DIC_20000101_20001231_1Y_ptrc_T.nc"
# sh d
# use "/home/biomac1/blevu/DATA/CARS2009/phosphate_cars2009.nc"
# use "/home/biomac2/jpalm/WOA/phosphate_annual_1deg.nc"
# use "/home/biomac1/blevu/DATA/CARS2009/nitrate_cars2009.nc"
# use "/home/biomac2/jpalm/WOA/nitrate_annual_1deg.nc"
# use "/home/biomac1/blevu/DATA/GLODAP/tco2_ann_Key.cdf"
# use "/home/biomac1/blevu/DATA/GLODAP/talk_ann_Key.cdf"
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">     currently SET data sets:
#     1> http://prodn.idris.fr/thredds/dodsC/IDRISPUBFS/rfry451/ORCA025-PIS2DIC/GRID/mask.nc
#  name     title                             I         J         K         L         M         N
#  NAV_LON                                   1:1442    1:1021    ...       ...       ...       ...
#  NAV_LAT                                   1:1442    1:1021    ...       ...       ...       ...
#  NAV_LEV                                   ...       ...       1:46      ...       ...       ...
#  TIME_COUNTER
#                                            ...       ...       ...       1:1       ...       ...
#  TMASK                                     1:1442    1:1021    1:46      1:1       ...       ...
#  UMASK                                     1:1442    1:1021    1:46      1:1       ...       ...
# ...

# %% [markdown]
# #### Define MYGRID to remove time axis of tmask which is in contradiction with time_counter axis of modele output

# %%
# %ferret_run 'def grid/x=x/y=y/z=z mygrid'

# %% [markdown]
# #### Define proper coordinates from MASK and MYGRID

# %%
# %%ferret
# let lon_masked=if TMASK[g=mygrid, d=1, k=1] eq 1 then nav_lon[d=1]
# let lat_masked=if TMASK[g=mygrid, d=1, k=1] eq 1 then nav_lat[d=1]
#
# set variable/units="degrees_east"/title="Longitude" lon_masked
# set variable/units="degrees_north"/title="Latitude" lat_masked

# %% [markdown]
# #### Set memories and subreg for big data

# %%
# %%ferret
# ! set mem/siz=300
#   def sym subreg=i=1:1442:4,j=1:1021:4

# %% [markdown]
# #### Plot masked PO4 at the surface in 2000 model & CARS (or WOA)

# %%
# %%ferret -q -s 800,400
# let var=PO4[d=2]/122*1e6
# let myvar=if TMASK[d=1,g=mygrid] eq 1 then var
#
# set win/size=1/new/aspect=1.2
# set viewport upper
# shade/hlim=0:360:30/vlim=-90:90:30/levels=(0,2,.2)/modulo myvar[k=2,l=1,($subreg)], lon_masked[($subreg)], lat_masked[($subreg)]
# go land
# go fland
#
# set viewport lower
# shade/hlim=0:360:30/vlim=-90:90:30/levels=(0,2,.2) mean[d=3,k=3]
# !shade/hlim=0:360:30/vlim=-90:90:30/levels=(0,2,.2) P_AN[d=4,k=3]
# go land
# go fland
# Out:
# <div class="myoutput"><img src="...

# %% [markdown]
# #### Plot masked NO3 at the surface in 2000 model & CARS (or WOA)

# %%
# %%ferret -q -s 800,400
# let var=NO3[d=2]*16/122*1e6
# let myvar=if TMASK[d=1,g=mygrid] eq 1 then var
#
# set win/size=1/new/aspect=1.2
# set viewport upper
# shade/hlim=0:360:30/vlim=-90:90:30/levels=(0,30,2)/modulo myvar[k=2,l=1,($subreg)], lon_masked[($subreg)], lat_masked[($subreg)]
# go land
# go fland
#
# set viewport lower
# shade/hlim=0:360:30/vlim=-90:90:30/levels=(0,30,2) mean[d=5,k=3]
# !shade/hlim=0:360:30/vlim=-90:90:30/levels=(0,30,2) N_AN[d=6,k=2]
# go land
# go fland
# Out:
# <div class="myoutput"><img src="...

# %% [markdown]
# #### Masked DIC at the surface in 2000 model & GLODAP

# %%
# %%ferret -q -s 800,400
# let var=DIC2[d=2]*1e6/1.028
# let myvar=if TMASK[d=1,g=mygrid] eq 1 then var
#
# set win/size=1/new/aspect=1.2
# set viewport upper
# shade/hlim=-180:180:30/vlim=-90:90:30/levels=(1500,2300,50)/modulo myvar[k=2,l=1,($subreg)], lon_masked[($subreg)], lat_masked[($subreg)]
# go land
# go fland
#
# set viewport lower
# shade/hlim=-180:180:30/vlim=-90:90:30/levels=(1500,2300,50) TCO2[d=7,k=2]
# go land
# go fland
# Out:
# <div class="myoutput"><img src="...

# %% [markdown]
# #### Masked TALK at the surface in 2000 model & GLODAP

# %%
# %%ferret -q -s 800,400
# let var=ALKALINI2[d=2]*1e6/1.028
# let myvar=if TMASK[d=1,g=mygrid] eq 1 then var
#
# set win/size=1/new/aspect=1.2
# set viewport upper
# shade/hlim=-180:180:30/vlim=-90:90:30/levels=(1600,2600,50)/modulo myvar[k=2,l=1,($subreg)], lon_masked[($subreg)], lat_masked[($subreg)]
# go land
# go fland
#
# set viewport lower
# shade/hlim=-180:180:30/vlim=-90:90:30/levels=(1600,2600,50) TALK[d=8,k=2]
# go land
# go fland
# Out:
# <div class="myoutput"><img src="...

# %% [markdown]
# First conclusion
# --
# Compared to data model outputs in 2000 has:
# * Nutrients too low in high latitudes and too high in gyres
# * TALK and DIC too low
#
# Perspective
# --
# * make a proper cliamto over ~10 years
# * Calculate N-star = (NO3 - 16*PO4 + 2.9) * 0.87 (GS97)
# * Si-star = SiO2 - NO3 (Setal2004)
# *...
